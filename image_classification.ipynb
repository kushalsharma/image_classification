# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('cifar-10-python.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# /anaconda2/envs/tensorflow/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: compiletime version 3.6 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.5
#   return f(*args, **kwds)
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 14
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 14:
# Image - Min Value: 1 Max Value: 255
# Image - Shape: (32, 32, 3)
# Label - Label Id: 9 Name: truck

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    minX = np.min(x);
    maxX = np.max(x);
    diff = maxX - minX;
    xArray = list()
    
    for singleX in x:
        xArray.append((singleX - minX) / diff)
    
    return np.array(xArray)

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# **Hint:**
#
# Look into LabelBinarizer in the preprocessing module of sklearn.

# %%
from sklearn.preprocessing import LabelBinarizer

label_binarize = LabelBinarizer()
label_binarize.fit(list(range(10)))

def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    
    return label_binarize.transform(x)

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    
    return tf.placeholder(tf.float32, shape=[None, image_shape[0], image_shape[1], image_shape[2]], name='x')


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """

    return tf.placeholder(tf.float32, shape=(None, n_classes), name="y")


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """

    return tf.placeholder(tf.float32, shape=(None), name='keep_prob')


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.
#
# ** Hint: **
#
# When unpacking values as an argument in Python, look into the [unpacking](https://docs.python.org/3/tutorial/controlflow.html#unpacking-argument-lists) operator.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """

    # weight
    weight = tf.Variable(tf.truncated_normal([conv_ksize[0], conv_ksize[1],
                                              x_tensor.get_shape().as_list()[3], conv_num_outputs], stddev=0.1))
    
    # bias
    bias = tf.Variable(tf.zeros(conv_num_outputs))

    # apply convolution
    conv = tf.nn.conv2d(x_tensor, weight, strides=[1, conv_strides[0], conv_strides[1], 1], padding='SAME')
    
    # apply bias
    conv = tf.nn.bias_add(conv, bias)
    
    # apply activation
    conv = tf.nn.relu(conv)
    
    # apply max pool
    conv = tf.nn.max_pool(conv, ksize=[1, pool_ksize[0], pool_ksize[1], 1], 
                          strides=[1, pool_strides[0], pool_strides[1], 1], padding='SAME')
    
    return conv 


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    shape = x_tensor.get_shape().as_list()
    dim = np.array(shape[1:]).prod()
    flatten_shape = tf.reshape(x_tensor, [tf.shape(x_tensor)[0], dim])
    
    return flatten_shape

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    
    shape = x_tensor.get_shape().as_list()
    flattened_shape = np.array(shape[1:]).prod()
    weights = tf.Variable(tf.truncated_normal([flattened_shape, num_outputs], stddev=0.04))
    bias = tf.Variable(tf.zeros(num_outputs))
    
    return tf.nn.relu(tf.add(tf.matmul(x_tensor, weights), bias))

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    
    shape = x_tensor.get_shape().as_list()
    flattened_shape = np.array(shape[1:]).prod()
    weights = tf.Variable(tf.truncated_normal([flattened_shape, num_outputs], stddev=0.04))
    bias = tf.Variable(tf.zeros(num_outputs))
    
    return tf.add(tf.matmul(x_tensor, weights), bias)

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    #    Play around with different number of outputs, kernel size and stride
    #    Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    conv = conv2d_maxpool(x, conv_num_outputs=32, conv_ksize=[5,5], conv_strides=[1,1], 
                          pool_ksize=[2,2], pool_strides=[2,2])
    conv = conv2d_maxpool(conv, conv_num_outputs=64, conv_ksize=[5,5], conv_strides=[1,1], 
                          pool_ksize=[2,2], pool_strides=[2,2])
    conv = conv2d_maxpool(conv, conv_num_outputs=128, conv_ksize=[5,5], conv_strides=[1,1], 
                          pool_ksize=[2,2], pool_strides=[2,2])
    
    

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    flattened_conv = flatten(conv)

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    
    full_conn = fully_conn(flattened_conv, 480)
    full_conn = fully_conn(full_conn, 240)
    full_conn = fully_conn(full_conn, 120)
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    fc = tf.nn.dropout(full_conn, keep_prob)
    
    # TODO: return output
    return output(fc, 10)

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# WARNING:tensorflow:From <ipython-input-13-37c04d683d77>:66: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See @{tf.nn.softmax_cross_entropy_with_logits_v2}.
#
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    session.run(optimizer, feed_dict={x: feature_batch, y: label_batch, keep_prob: keep_probability})

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    loss = sess.run(cost, feed_dict={x: feature_batch,
                                     y: label_batch,
                                     keep_prob: 1.})
    valid_acc = sess.run(accuracy, feed_dict={x: valid_features,
                                              y: valid_labels,
                                              keep_prob: 1.})

    print('Loss: {:>10.4f} Validation Accuracy: {:.6f}'.format(loss, valid_acc))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
epochs = 80
batch_size = 256
keep_probability = 0.81

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Loss:     2.2024 Validation Accuracy: 0.302200
# Epoch  2, CIFAR-10 Batch 1:  Loss:     1.7936 Validation Accuracy: 0.388400
# Epoch  3, CIFAR-10 Batch 1:  Loss:     1.4374 Validation Accuracy: 0.416400
# Epoch  4, CIFAR-10 Batch 1:  Loss:     1.2294 Validation Accuracy: 0.431800
# Epoch  5, CIFAR-10 Batch 1:  Loss:     1.0136 Validation Accuracy: 0.480400
# Epoch  6, CIFAR-10 Batch 1:  Loss:     0.9548 Validation Accuracy: 0.457200
# Epoch  7, CIFAR-10 Batch 1:  Loss:     0.6381 Validation Accuracy: 0.517000
# Epoch  8, CIFAR-10 Batch 1:  Loss:     0.3989 Validation Accuracy: 0.546400
# Epoch  9, CIFAR-10 Batch 1:  Loss:     0.3910 Validation Accuracy: 0.473400
# Epoch 10, CIFAR-10 Batch 1:  Loss:     0.3034 Validation Accuracy: 0.521200
# Epoch 11, CIFAR-10 Batch 1:  Loss:     0.1931 Validation Accuracy: 0.545000
# Epoch 12, CIFAR-10 Batch 1:  Loss:     0.1482 Validation Accuracy: 0.571800
# Epoch 13, CIFAR-10 Batch 1:  Loss:     0.1070 Validation Accuracy: 0.540200
# Epoch 14, CIFAR-10 Batch 1:  Loss:     0.1259 Validation Accuracy: 0.508600
# Epoch 15, CIFAR-10 Batch 1:  Loss:     0.0854 Validation Accuracy: 0.516600
# Epoch 16, CIFAR-10 Batch 1:  Loss:     0.0481 Validation Accuracy: 0.501400
# Epoch 17, CIFAR-10 Batch 1:  Loss:     0.0833 Validation Accuracy: 0.524400
# Epoch 18, CIFAR-10 Batch 1:  Loss:     0.0469 Validation Accuracy: 0.528800
# Epoch 19, CIFAR-10 Batch 1:  Loss:     0.0156 Validation Accuracy: 0.546600
# Epoch 20, CIFAR-10 Batch 1:  Loss:     0.0158 Validation Accuracy: 0.549800
# Epoch 21, CIFAR-10 Batch 1:  Loss:     0.0259 Validation Accuracy: 0.518000
# Epoch 22, CIFAR-10 Batch 1:  Loss:     0.0180 Validation Accuracy: 0.563600
# Epoch 23, CIFAR-10 Batch 1:  Loss:     0.0088 Validation Accuracy: 0.563400
# Epoch 24, CIFAR-10 Batch 1:  Loss:     0.0156 Validation Accuracy: 0.561200
# Epoch 25, CIFAR-10 Batch 1:  Loss:     0.0055 Validation Accuracy: 0.547600
# Epoch 26, CIFAR-10 Batch 1:  Loss:     0.0042 Validation Accuracy: 0.550600
# Epoch 27, CIFAR-10 Batch 1:  Loss:     0.0043 Validation Accuracy: 0.539800
# Epoch 28, CIFAR-10 Batch 1:  Loss:     0.0034 Validation Accuracy: 0.554800
# Epoch 29, CIFAR-10 Batch 1:  Loss:     0.0029 Validation Accuracy: 0.546800
# Epoch 30, CIFAR-10 Batch 1:  Loss:     0.0025 Validation Accuracy: 0.564000
# Epoch 31, CIFAR-10 Batch 1:  Loss:     0.0027 Validation Accuracy: 0.561000
# Epoch 32, CIFAR-10 Batch 1:  Loss:     0.0003 Validation Accuracy: 0.573600
# Epoch 33, CIFAR-10 Batch 1:  Loss:     0.0002 Validation Accuracy: 0.570600
# Epoch 34, CIFAR-10 Batch 1:  Loss:     0.0008 Validation Accuracy: 0.560200
# Epoch 35, CIFAR-10 Batch 1:  Loss:     0.0002 Validation Accuracy: 0.578400
# Epoch 36, CIFAR-10 Batch 1:  Loss:     0.0003 Validation Accuracy: 0.561600
# Epoch 37, CIFAR-10 Batch 1:  Loss:     0.0003 Validation Accuracy: 0.567800
# Epoch 38, CIFAR-10 Batch 1:  Loss:     0.0001 Validation Accuracy: 0.582000
# Epoch 39, CIFAR-10 Batch 1:  Loss:     0.0001 Validation Accuracy: 0.581200
# Epoch 40, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.587200
# Epoch 41, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.589800
# Epoch 42, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.591800
# Epoch 43, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.593600
# Epoch 44, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.592800
# Epoch 45, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.594000
# Epoch 46, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.595200
# Epoch 47, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.598200
# Epoch 48, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.595200
# Epoch 49, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.594600
# Epoch 50, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.597400
# Epoch 51, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.594400
# Epoch 52, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.595200
# Epoch 53, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.595800
# Epoch 54, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.594000
# Epoch 55, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.596000
# Epoch 56, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.596000
# Epoch 57, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.591800
# Epoch 58, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.596800
# Epoch 59, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.597000
# Epoch 60, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.596800
# Epoch 61, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.597000
# Epoch 62, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.597200
# Epoch 63, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.597400
# Epoch 64, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.595000
# Epoch 65, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.596000
# Epoch 66, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.597400
# Epoch 67, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.596400
# Epoch 68, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.597800
# Epoch 69, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.595000
# Epoch 70, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.595200
# Epoch 71, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.592800
# Epoch 72, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.597200
# Epoch 73, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.596800
# Epoch 74, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.596200
# Epoch 75, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.594800
# Epoch 76, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.596400
# Epoch 77, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.596600
# Epoch 78, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.596800
# Epoch 79, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.595600
# Epoch 80, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.597200

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Loss:     2.0865 Validation Accuracy: 0.300800
# Epoch  1, CIFAR-10 Batch 2:  Loss:     1.6612 Validation Accuracy: 0.393600
# Epoch  1, CIFAR-10 Batch 3:  Loss:     1.4266 Validation Accuracy: 0.392400
# Epoch  1, CIFAR-10 Batch 4:  Loss:     1.3819 Validation Accuracy: 0.473800
# Epoch  1, CIFAR-10 Batch 5:  Loss:     1.3749 Validation Accuracy: 0.507600
# Epoch  2, CIFAR-10 Batch 1:  Loss:     1.3843 Validation Accuracy: 0.500400
# Epoch  2, CIFAR-10 Batch 2:  Loss:     1.2015 Validation Accuracy: 0.497200
# Epoch  2, CIFAR-10 Batch 3:  Loss:     0.8724 Validation Accuracy: 0.522200
# Epoch  2, CIFAR-10 Batch 4:  Loss:     1.0531 Validation Accuracy: 0.555600
# Epoch  2, CIFAR-10 Batch 5:  Loss:     0.9721 Validation Accuracy: 0.552200
# Epoch  3, CIFAR-10 Batch 1:  Loss:     1.0027 Validation Accuracy: 0.569400
# Epoch  3, CIFAR-10 Batch 2:  Loss:     0.7710 Validation Accuracy: 0.589800
# Epoch  3, CIFAR-10 Batch 3:  Loss:     0.5741 Validation Accuracy: 0.575000
# Epoch  3, CIFAR-10 Batch 4:  Loss:     0.7708 Validation Accuracy: 0.598800
# Epoch  3, CIFAR-10 Batch 5:  Loss:     0.6743 Validation Accuracy: 0.618400
# Epoch  4, CIFAR-10 Batch 1:  Loss:     0.6697 Validation Accuracy: 0.601000
# Epoch  4, CIFAR-10 Batch 2:  Loss:     0.5037 Validation Accuracy: 0.596200
# Epoch  4, CIFAR-10 Batch 3:  Loss:     0.3467 Validation Accuracy: 0.600800
# Epoch  4, CIFAR-10 Batch 4:  Loss:     0.4694 Validation Accuracy: 0.638200
# Epoch  4, CIFAR-10 Batch 5:  Loss:     0.4618 Validation Accuracy: 0.629400
# Epoch  5, CIFAR-10 Batch 1:  Loss:     0.4736 Validation Accuracy: 0.657800
# Epoch  5, CIFAR-10 Batch 2:  Loss:     0.3072 Validation Accuracy: 0.641000
# Epoch  5, CIFAR-10 Batch 3:  Loss:     0.2012 Validation Accuracy: 0.650800
# Epoch  5, CIFAR-10 Batch 4:  Loss:     0.2952 Validation Accuracy: 0.664400
# Epoch  5, CIFAR-10 Batch 5:  Loss:     0.2479 Validation Accuracy: 0.668000
# Epoch  6, CIFAR-10 Batch 1:  Loss:     0.3739 Validation Accuracy: 0.640800
# Epoch  6, CIFAR-10 Batch 2:  Loss:     0.1909 Validation Accuracy: 0.651600
# Epoch  6, CIFAR-10 Batch 3:  Loss:     0.1508 Validation Accuracy: 0.640000
# Epoch  6, CIFAR-10 Batch 4:  Loss:     0.2488 Validation Accuracy: 0.630800
# Epoch  6, CIFAR-10 Batch 5:  Loss:     0.1381 Validation Accuracy: 0.646600
# Epoch  7, CIFAR-10 Batch 1:  Loss:     0.2328 Validation Accuracy: 0.672800
# Epoch  7, CIFAR-10 Batch 2:  Loss:     0.1126 Validation Accuracy: 0.658200
# Epoch  7, CIFAR-10 Batch 3:  Loss:     0.1370 Validation Accuracy: 0.655800
# Epoch  7, CIFAR-10 Batch 4:  Loss:     0.2083 Validation Accuracy: 0.638400
# Epoch  7, CIFAR-10 Batch 5:  Loss:     0.1167 Validation Accuracy: 0.648200
# Epoch  8, CIFAR-10 Batch 1:  Loss:     0.1607 Validation Accuracy: 0.637800
# Epoch  8, CIFAR-10 Batch 2:  Loss:     0.0827 Validation Accuracy: 0.672600
# Epoch  8, CIFAR-10 Batch 3:  Loss:     0.0928 Validation Accuracy: 0.630200
# Epoch  8, CIFAR-10 Batch 4:  Loss:     0.0997 Validation Accuracy: 0.670200
# Epoch  8, CIFAR-10 Batch 5:  Loss:     0.0598 Validation Accuracy: 0.686400
# Epoch  9, CIFAR-10 Batch 1:  Loss:     0.0713 Validation Accuracy: 0.668800
# Epoch  9, CIFAR-10 Batch 2:  Loss:     0.0872 Validation Accuracy: 0.673600
# Epoch  9, CIFAR-10 Batch 3:  Loss:     0.0719 Validation Accuracy: 0.652600
# Epoch  9, CIFAR-10 Batch 4:  Loss:     0.0779 Validation Accuracy: 0.652800
# Epoch  9, CIFAR-10 Batch 5:  Loss:     0.0721 Validation Accuracy: 0.639600
# Epoch 10, CIFAR-10 Batch 1:  Loss:     0.0740 Validation Accuracy: 0.676000
# Epoch 10, CIFAR-10 Batch 2:  Loss:     0.0571 Validation Accuracy: 0.655800
# Epoch 10, CIFAR-10 Batch 3:  Loss:     0.0477 Validation Accuracy: 0.660600
# Epoch 10, CIFAR-10 Batch 4:  Loss:     0.0485 Validation Accuracy: 0.671800
# Epoch 10, CIFAR-10 Batch 5:  Loss:     0.0411 Validation Accuracy: 0.652200
# Epoch 11, CIFAR-10 Batch 1:  Loss:     0.0432 Validation Accuracy: 0.668600
# Epoch 11, CIFAR-10 Batch 2:  Loss:     0.0712 Validation Accuracy: 0.637200
# Epoch 11, CIFAR-10 Batch 3:  Loss:     0.0341 Validation Accuracy: 0.660600
# Epoch 11, CIFAR-10 Batch 4:  Loss:     0.0377 Validation Accuracy: 0.673600
# Epoch 11, CIFAR-10 Batch 5:  Loss:     0.0212 Validation Accuracy: 0.659800
# Epoch 12, CIFAR-10 Batch 1:  Loss:     0.0155 Validation Accuracy: 0.673400
# Epoch 12, CIFAR-10 Batch 2:  Loss:     0.0235 Validation Accuracy: 0.676600
# Epoch 12, CIFAR-10 Batch 3:  Loss:     0.0162 Validation Accuracy: 0.675800
# Epoch 12, CIFAR-10 Batch 4:  Loss:     0.0387 Validation Accuracy: 0.659600
# Epoch 12, CIFAR-10 Batch 5:  Loss:     0.0127 Validation Accuracy: 0.680000
# Epoch 13, CIFAR-10 Batch 1:  Loss:     0.0121 Validation Accuracy: 0.684000
# Epoch 13, CIFAR-10 Batch 2:  Loss:     0.0182 Validation Accuracy: 0.670000
# Epoch 13, CIFAR-10 Batch 3:  Loss:     0.0073 Validation Accuracy: 0.676000
# Epoch 13, CIFAR-10 Batch 4:  Loss:     0.0324 Validation Accuracy: 0.661400
# Epoch 13, CIFAR-10 Batch 5:  Loss:     0.0076 Validation Accuracy: 0.685200
# Epoch 14, CIFAR-10 Batch 1:  Loss:     0.0235 Validation Accuracy: 0.677200
# Epoch 14, CIFAR-10 Batch 2:  Loss:     0.0225 Validation Accuracy: 0.662200
# Epoch 14, CIFAR-10 Batch 3:  Loss:     0.0128 Validation Accuracy: 0.656000
# Epoch 14, CIFAR-10 Batch 4:  Loss:     0.0186 Validation Accuracy: 0.669200
# Epoch 14, CIFAR-10 Batch 5:  Loss:     0.0123 Validation Accuracy: 0.679200
# Epoch 15, CIFAR-10 Batch 1:  Loss:     0.0155 Validation Accuracy: 0.659000
# Epoch 15, CIFAR-10 Batch 2:  Loss:     0.0116 Validation Accuracy: 0.647400
# Epoch 15, CIFAR-10 Batch 3:  Loss:     0.0142 Validation Accuracy: 0.655800
# Epoch 15, CIFAR-10 Batch 4:  Loss:     0.0085 Validation Accuracy: 0.670800
# Epoch 15, CIFAR-10 Batch 5:  Loss:     0.0141 Validation Accuracy: 0.672200
# Epoch 16, CIFAR-10 Batch 1:  Loss:     0.0052 Validation Accuracy: 0.680200
# Epoch 16, CIFAR-10 Batch 2:  Loss:     0.0068 Validation Accuracy: 0.648600
# Epoch 16, CIFAR-10 Batch 3:  Loss:     0.0063 Validation Accuracy: 0.660000
# Epoch 16, CIFAR-10 Batch 4:  Loss:     0.0078 Validation Accuracy: 0.669000
# Epoch 16, CIFAR-10 Batch 5:  Loss:     0.0039 Validation Accuracy: 0.685400
# Epoch 17, CIFAR-10 Batch 1:  Loss:     0.0017 Validation Accuracy: 0.687400
# Epoch 17, CIFAR-10 Batch 2:  Loss:     0.0038 Validation Accuracy: 0.672800
# Epoch 17, CIFAR-10 Batch 3:  Loss:     0.0042 Validation Accuracy: 0.668000
# Epoch 17, CIFAR-10 Batch 4:  Loss:     0.0143 Validation Accuracy: 0.655400
# Epoch 17, CIFAR-10 Batch 5:  Loss:     0.0073 Validation Accuracy: 0.674400
# Epoch 18, CIFAR-10 Batch 1:  Loss:     0.0022 Validation Accuracy: 0.679600
# Epoch 18, CIFAR-10 Batch 2:  Loss:     0.0025 Validation Accuracy: 0.658400
# Epoch 18, CIFAR-10 Batch 3:  Loss:     0.0057 Validation Accuracy: 0.666400
# Epoch 18, CIFAR-10 Batch 4:  Loss:     0.0080 Validation Accuracy: 0.665800
# Epoch 18, CIFAR-10 Batch 5:  Loss:     0.0041 Validation Accuracy: 0.672600
# Epoch 19, CIFAR-10 Batch 1:  Loss:     0.0074 Validation Accuracy: 0.665400
# Epoch 19, CIFAR-10 Batch 2:  Loss:     0.0021 Validation Accuracy: 0.660600
# Epoch 19, CIFAR-10 Batch 3:  Loss:     0.0017 Validation Accuracy: 0.668800
# Epoch 19, CIFAR-10 Batch 4:  Loss:     0.0025 Validation Accuracy: 0.669600
# Epoch 19, CIFAR-10 Batch 5:  Loss:     0.0025 Validation Accuracy: 0.667200
# Epoch 20, CIFAR-10 Batch 1:  Loss:     0.0041 Validation Accuracy: 0.658200
# Epoch 20, CIFAR-10 Batch 2:  Loss:     0.0037 Validation Accuracy: 0.666800
# Epoch 20, CIFAR-10 Batch 3:  Loss:     0.0066 Validation Accuracy: 0.653600
# Epoch 20, CIFAR-10 Batch 4:  Loss:     0.0021 Validation Accuracy: 0.673600
# Epoch 20, CIFAR-10 Batch 5:  Loss:     0.0039 Validation Accuracy: 0.679800
# Epoch 21, CIFAR-10 Batch 1:  Loss:     0.0025 Validation Accuracy: 0.664400
# Epoch 21, CIFAR-10 Batch 2:  Loss:     0.0051 Validation Accuracy: 0.668800
# Epoch 21, CIFAR-10 Batch 3:  Loss:     0.0086 Validation Accuracy: 0.653200
# Epoch 21, CIFAR-10 Batch 4:  Loss:     0.0025 Validation Accuracy: 0.665600
# Epoch 21, CIFAR-10 Batch 5:  Loss:     0.0022 Validation Accuracy: 0.686200
# Epoch 22, CIFAR-10 Batch 1:  Loss:     0.0049 Validation Accuracy: 0.667000
# Epoch 22, CIFAR-10 Batch 2:  Loss:     0.0084 Validation Accuracy: 0.668600
# Epoch 22, CIFAR-10 Batch 3:  Loss:     0.0061 Validation Accuracy: 0.648400
# Epoch 22, CIFAR-10 Batch 4:  Loss:     0.0019 Validation Accuracy: 0.680800
# Epoch 22, CIFAR-10 Batch 5:  Loss:     0.0014 Validation Accuracy: 0.673200
# Epoch 23, CIFAR-10 Batch 1:  Loss:     0.0012 Validation Accuracy: 0.684400
# Epoch 23, CIFAR-10 Batch 2:  Loss:     0.0008 Validation Accuracy: 0.670000
# Epoch 23, CIFAR-10 Batch 3:  Loss:     0.0040 Validation Accuracy: 0.650000
# Epoch 23, CIFAR-10 Batch 4:  Loss:     0.0011 Validation Accuracy: 0.679200
# Epoch 23, CIFAR-10 Batch 5:  Loss:     0.0033 Validation Accuracy: 0.655400
# Epoch 24, CIFAR-10 Batch 1:  Loss:     0.0069 Validation Accuracy: 0.676200
# Epoch 24, CIFAR-10 Batch 2:  Loss:     0.0015 Validation Accuracy: 0.670400
# Epoch 24, CIFAR-10 Batch 3:  Loss:     0.0016 Validation Accuracy: 0.685800
# Epoch 24, CIFAR-10 Batch 4:  Loss:     0.0006 Validation Accuracy: 0.679000
# Epoch 24, CIFAR-10 Batch 5:  Loss:     0.0007 Validation Accuracy: 0.693400
# Epoch 25, CIFAR-10 Batch 1:  Loss:     0.0003 Validation Accuracy: 0.699000
# Epoch 25, CIFAR-10 Batch 2:  Loss:     0.0013 Validation Accuracy: 0.685000
# Epoch 25, CIFAR-10 Batch 3:  Loss:     0.0002 Validation Accuracy: 0.689200
# Epoch 25, CIFAR-10 Batch 4:  Loss:     0.0007 Validation Accuracy: 0.678600
# Epoch 25, CIFAR-10 Batch 5:  Loss:     0.0006 Validation Accuracy: 0.696200
# Epoch 26, CIFAR-10 Batch 1:  Loss:     0.0006 Validation Accuracy: 0.696800
# Epoch 26, CIFAR-10 Batch 2:  Loss:     0.0002 Validation Accuracy: 0.682200
# Epoch 26, CIFAR-10 Batch 3:  Loss:     0.0005 Validation Accuracy: 0.686400
# Epoch 26, CIFAR-10 Batch 4:  Loss:     0.0005 Validation Accuracy: 0.681000
# Epoch 26, CIFAR-10 Batch 5:  Loss:     0.0007 Validation Accuracy: 0.688800
# Epoch 27, CIFAR-10 Batch 1:  Loss:     0.0004 Validation Accuracy: 0.685600
# Epoch 27, CIFAR-10 Batch 2:  Loss:     0.0004 Validation Accuracy: 0.692200
# Epoch 27, CIFAR-10 Batch 3:  Loss:     0.0006 Validation Accuracy: 0.681800
# Epoch 27, CIFAR-10 Batch 4:  Loss:     0.0004 Validation Accuracy: 0.670200
# Epoch 27, CIFAR-10 Batch 5:  Loss:     0.0008 Validation Accuracy: 0.683000
# Epoch 28, CIFAR-10 Batch 1:  Loss:     0.0066 Validation Accuracy: 0.690200
# Epoch 28, CIFAR-10 Batch 2:  Loss:     0.0008 Validation Accuracy: 0.694600
# Epoch 28, CIFAR-10 Batch 3:  Loss:     0.0004 Validation Accuracy: 0.680400
# Epoch 28, CIFAR-10 Batch 4:  Loss:     0.0002 Validation Accuracy: 0.680600
# Epoch 28, CIFAR-10 Batch 5:  Loss:     0.0002 Validation Accuracy: 0.675200
# Epoch 29, CIFAR-10 Batch 1:  Loss:     0.0008 Validation Accuracy: 0.697000
# Epoch 29, CIFAR-10 Batch 2:  Loss:     0.0002 Validation Accuracy: 0.689800
# Epoch 29, CIFAR-10 Batch 3:  Loss:     0.0004 Validation Accuracy: 0.687600
# Epoch 29, CIFAR-10 Batch 4:  Loss:     0.0001 Validation Accuracy: 0.683800
# Epoch 29, CIFAR-10 Batch 5:  Loss:     0.0006 Validation Accuracy: 0.685600
# Epoch 30, CIFAR-10 Batch 1:  Loss:     0.0003 Validation Accuracy: 0.691600
# Epoch 30, CIFAR-10 Batch 2:  Loss:     0.0015 Validation Accuracy: 0.686800
# Epoch 30, CIFAR-10 Batch 3:  Loss:     0.0006 Validation Accuracy: 0.688400
# Epoch 30, CIFAR-10 Batch 4:  Loss:     0.0002 Validation Accuracy: 0.691000
# Epoch 30, CIFAR-10 Batch 5:  Loss:     0.0038 Validation Accuracy: 0.688000
# Epoch 31, CIFAR-10 Batch 1:  Loss:     0.0010 Validation Accuracy: 0.681600
# Epoch 31, CIFAR-10 Batch 2:  Loss:     0.0002 Validation Accuracy: 0.688400
# Epoch 31, CIFAR-10 Batch 3:  Loss:     0.0019 Validation Accuracy: 0.684200
# Epoch 31, CIFAR-10 Batch 4:  Loss:     0.0033 Validation Accuracy: 0.677200
# Epoch 31, CIFAR-10 Batch 5:  Loss:     0.0000 Validation Accuracy: 0.679800
# Epoch 32, CIFAR-10 Batch 1:  Loss:     0.0010 Validation Accuracy: 0.681600
# Epoch 32, CIFAR-10 Batch 2:  Loss:     0.0004 Validation Accuracy: 0.682600
# Epoch 32, CIFAR-10 Batch 3:  Loss:     0.0002 Validation Accuracy: 0.686800
# Epoch 32, CIFAR-10 Batch 4:  Loss:     0.0008 Validation Accuracy: 0.660400
# Epoch 32, CIFAR-10 Batch 5:  Loss:     0.0017 Validation Accuracy: 0.681800
# Epoch 33, CIFAR-10 Batch 1:  Loss:     0.0002 Validation Accuracy: 0.689200
# Epoch 33, CIFAR-10 Batch 2:  Loss:     0.0003 Validation Accuracy: 0.676800
# Epoch 33, CIFAR-10 Batch 3:  Loss:     0.0006 Validation Accuracy: 0.677000
# Epoch 33, CIFAR-10 Batch 4:  Loss:     0.0003 Validation Accuracy: 0.666600
# Epoch 33, CIFAR-10 Batch 5:  Loss:     0.0003 Validation Accuracy: 0.685200
# Epoch 34, CIFAR-10 Batch 1:  Loss:     0.0008 Validation Accuracy: 0.688400
# Epoch 34, CIFAR-10 Batch 2:  Loss:     0.0003 Validation Accuracy: 0.693400
# Epoch 34, CIFAR-10 Batch 3:  Loss:     0.0008 Validation Accuracy: 0.691800
# Epoch 34, CIFAR-10 Batch 4:  Loss:     0.0001 Validation Accuracy: 0.695400
# Epoch 34, CIFAR-10 Batch 5:  Loss:     0.0006 Validation Accuracy: 0.679600
# Epoch 35, CIFAR-10 Batch 1:  Loss:     0.0002 Validation Accuracy: 0.686400
# Epoch 35, CIFAR-10 Batch 2:  Loss:     0.0003 Validation Accuracy: 0.693200
# Epoch 35, CIFAR-10 Batch 3:  Loss:     0.0003 Validation Accuracy: 0.690000
# Epoch 35, CIFAR-10 Batch 4:  Loss:     0.0002 Validation Accuracy: 0.696800
# Epoch 35, CIFAR-10 Batch 5:  Loss:     0.0087 Validation Accuracy: 0.689600
# Epoch 36, CIFAR-10 Batch 1:  Loss:     0.0005 Validation Accuracy: 0.670000
# Epoch 36, CIFAR-10 Batch 2:  Loss:     0.0003 Validation Accuracy: 0.681200
# Epoch 36, CIFAR-10 Batch 3:  Loss:     0.0002 Validation Accuracy: 0.684000
# Epoch 36, CIFAR-10 Batch 4:  Loss:     0.0004 Validation Accuracy: 0.681200
# Epoch 36, CIFAR-10 Batch 5:  Loss:     0.0004 Validation Accuracy: 0.676200
# Epoch 37, CIFAR-10 Batch 1:  Loss:     0.0009 Validation Accuracy: 0.667800
# Epoch 37, CIFAR-10 Batch 2:  Loss:     0.0013 Validation Accuracy: 0.687200
# Epoch 37, CIFAR-10 Batch 3:  Loss:     0.0007 Validation Accuracy: 0.688600
# Epoch 37, CIFAR-10 Batch 4:  Loss:     0.0021 Validation Accuracy: 0.691000
# Epoch 37, CIFAR-10 Batch 5:  Loss:     0.0003 Validation Accuracy: 0.695400
# Epoch 38, CIFAR-10 Batch 1:  Loss:     0.0005 Validation Accuracy: 0.679200
# Epoch 38, CIFAR-10 Batch 2:  Loss:     0.0003 Validation Accuracy: 0.673000
# Epoch 38, CIFAR-10 Batch 3:  Loss:     0.0005 Validation Accuracy: 0.674200
# Epoch 38, CIFAR-10 Batch 4:  Loss:     0.0003 Validation Accuracy: 0.693200
# Epoch 38, CIFAR-10 Batch 5:  Loss:     0.0000 Validation Accuracy: 0.673800
# Epoch 39, CIFAR-10 Batch 1:  Loss:     0.0007 Validation Accuracy: 0.682600
# Epoch 39, CIFAR-10 Batch 2:  Loss:     0.0006 Validation Accuracy: 0.676400
# Epoch 39, CIFAR-10 Batch 3:  Loss:     0.0004 Validation Accuracy: 0.669200
# Epoch 39, CIFAR-10 Batch 4:  Loss:     0.0007 Validation Accuracy: 0.697400
# Epoch 39, CIFAR-10 Batch 5:  Loss:     0.0003 Validation Accuracy: 0.686000
# Epoch 40, CIFAR-10 Batch 1:  Loss:     0.0002 Validation Accuracy: 0.667800
# Epoch 40, CIFAR-10 Batch 2:  Loss:     0.0007 Validation Accuracy: 0.688200
# Epoch 40, CIFAR-10 Batch 3:  Loss:     0.0001 Validation Accuracy: 0.690600
# Epoch 40, CIFAR-10 Batch 4:  Loss:     0.0005 Validation Accuracy: 0.690200
# Epoch 40, CIFAR-10 Batch 5:  Loss:     0.0001 Validation Accuracy: 0.688800
# Epoch 41, CIFAR-10 Batch 1:  Loss:     0.0008 Validation Accuracy: 0.672400
# Epoch 41, CIFAR-10 Batch 2:  Loss:     0.0006 Validation Accuracy: 0.692600
# Epoch 41, CIFAR-10 Batch 3:  Loss:     0.0008 Validation Accuracy: 0.683000
# Epoch 41, CIFAR-10 Batch 4:  Loss:     0.0019 Validation Accuracy: 0.698400
# Epoch 41, CIFAR-10 Batch 5:  Loss:     0.0004 Validation Accuracy: 0.689600
# Epoch 42, CIFAR-10 Batch 1:  Loss:     0.0012 Validation Accuracy: 0.660400
# Epoch 42, CIFAR-10 Batch 2:  Loss:     0.0007 Validation Accuracy: 0.700600
# Epoch 42, CIFAR-10 Batch 3:  Loss:     0.0016 Validation Accuracy: 0.682200
# Epoch 42, CIFAR-10 Batch 4:  Loss:     0.0011 Validation Accuracy: 0.682800
# Epoch 42, CIFAR-10 Batch 5:  Loss:     0.0006 Validation Accuracy: 0.686000
# Epoch 43, CIFAR-10 Batch 1:  Loss:     0.0011 Validation Accuracy: 0.691000
# Epoch 43, CIFAR-10 Batch 2:  Loss:     0.0004 Validation Accuracy: 0.691600
# Epoch 43, CIFAR-10 Batch 3:  Loss:     0.0001 Validation Accuracy: 0.689600
# Epoch 43, CIFAR-10 Batch 4:  Loss:     0.0002 Validation Accuracy: 0.689600
# Epoch 43, CIFAR-10 Batch 5:  Loss:     0.0006 Validation Accuracy: 0.687000
# Epoch 44, CIFAR-10 Batch 1:  Loss:     0.0007 Validation Accuracy: 0.695000
# Epoch 44, CIFAR-10 Batch 2:  Loss:     0.0005 Validation Accuracy: 0.690800
# Epoch 44, CIFAR-10 Batch 3:  Loss:     0.0001 Validation Accuracy: 0.698200
# Epoch 44, CIFAR-10 Batch 4:  Loss:     0.0005 Validation Accuracy: 0.684600
# Epoch 44, CIFAR-10 Batch 5:  Loss:     0.0000 Validation Accuracy: 0.694200
# Epoch 45, CIFAR-10 Batch 1:  Loss:     0.0006 Validation Accuracy: 0.696800
# Epoch 45, CIFAR-10 Batch 2:  Loss:     0.0021 Validation Accuracy: 0.685800
# Epoch 45, CIFAR-10 Batch 3:  Loss:     0.0005 Validation Accuracy: 0.686000
# Epoch 45, CIFAR-10 Batch 4:  Loss:     0.0026 Validation Accuracy: 0.691800
# Epoch 45, CIFAR-10 Batch 5:  Loss:     0.0009 Validation Accuracy: 0.688600
# Epoch 46, CIFAR-10 Batch 1:  Loss:     0.0005 Validation Accuracy: 0.685400
# Epoch 46, CIFAR-10 Batch 2:  Loss:     0.0002 Validation Accuracy: 0.684400
# Epoch 46, CIFAR-10 Batch 3:  Loss:     0.0004 Validation Accuracy: 0.690000
# Epoch 46, CIFAR-10 Batch 4:  Loss:     0.0003 Validation Accuracy: 0.685800
# Epoch 46, CIFAR-10 Batch 5:  Loss:     0.0001 Validation Accuracy: 0.684400
# Epoch 47, CIFAR-10 Batch 1:  Loss:     0.0013 Validation Accuracy: 0.685400
# Epoch 47, CIFAR-10 Batch 2:  Loss:     0.0001 Validation Accuracy: 0.685800
# Epoch 47, CIFAR-10 Batch 3:  Loss:     0.0002 Validation Accuracy: 0.687800
# Epoch 47, CIFAR-10 Batch 4:  Loss:     0.0014 Validation Accuracy: 0.676000
# Epoch 47, CIFAR-10 Batch 5:  Loss:     0.0017 Validation Accuracy: 0.691000
# Epoch 48, CIFAR-10 Batch 1:  Loss:     0.0003 Validation Accuracy: 0.696000
# Epoch 48, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy: 0.689600
# Epoch 48, CIFAR-10 Batch 3:  Loss:     0.0002 Validation Accuracy: 0.681200
# Epoch 48, CIFAR-10 Batch 4:  Loss:     0.0003 Validation Accuracy: 0.682200
# Epoch 48, CIFAR-10 Batch 5:  Loss:     0.0002 Validation Accuracy: 0.681000
# Epoch 49, CIFAR-10 Batch 1:  Loss:     0.0001 Validation Accuracy: 0.694000
# Epoch 49, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy: 0.693400
# Epoch 49, CIFAR-10 Batch 3:  Loss:     0.0006 Validation Accuracy: 0.685800
# Epoch 49, CIFAR-10 Batch 4:  Loss:     0.0001 Validation Accuracy: 0.686200
# Epoch 49, CIFAR-10 Batch 5:  Loss:     0.0001 Validation Accuracy: 0.687200
# Epoch 50, CIFAR-10 Batch 1:  Loss:     0.0006 Validation Accuracy: 0.689000
# Epoch 50, CIFAR-10 Batch 2:  Loss:     0.0003 Validation Accuracy: 0.697600
# Epoch 50, CIFAR-10 Batch 3:  Loss:     0.0005 Validation Accuracy: 0.681200
# Epoch 50, CIFAR-10 Batch 4:  Loss:     0.0002 Validation Accuracy: 0.682600
# Epoch 50, CIFAR-10 Batch 5:  Loss:     0.0004 Validation Accuracy: 0.691000
# Epoch 51, CIFAR-10 Batch 1:  Loss:     0.0024 Validation Accuracy: 0.699400
# Epoch 51, CIFAR-10 Batch 2:  Loss:     0.0005 Validation Accuracy: 0.694400
# Epoch 51, CIFAR-10 Batch 3:  Loss:     0.0001 Validation Accuracy: 0.688400
# Epoch 51, CIFAR-10 Batch 4:  Loss:     0.0003 Validation Accuracy: 0.693000
# Epoch 51, CIFAR-10 Batch 5:  Loss:     0.0000 Validation Accuracy: 0.688000
# Epoch 52, CIFAR-10 Batch 1:  Loss:     0.0004 Validation Accuracy: 0.691000
# Epoch 52, CIFAR-10 Batch 2:  Loss:     0.0003 Validation Accuracy: 0.692000
# Epoch 52, CIFAR-10 Batch 3:  Loss:     0.0001 Validation Accuracy: 0.694800
# Epoch 52, CIFAR-10 Batch 4:  Loss:     0.0000 Validation Accuracy: 0.694200
# Epoch 52, CIFAR-10 Batch 5:  Loss:     0.0004 Validation Accuracy: 0.694400
# Epoch 53, CIFAR-10 Batch 1:  Loss:     0.0008 Validation Accuracy: 0.690200
# Epoch 53, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy: 0.687000
# Epoch 53, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy: 0.697400
# Epoch 53, CIFAR-10 Batch 4:  Loss:     0.0005 Validation Accuracy: 0.689000
# Epoch 53, CIFAR-10 Batch 5:  Loss:     0.0002 Validation Accuracy: 0.693400
# Epoch 54, CIFAR-10 Batch 1:  Loss:     0.0005 Validation Accuracy: 0.696200
# Epoch 54, CIFAR-10 Batch 2:  Loss:     0.0007 Validation Accuracy: 0.704000
# Epoch 54, CIFAR-10 Batch 3:  Loss:     0.0001 Validation Accuracy: 0.697600
# Epoch 54, CIFAR-10 Batch 4:  Loss:     0.0005 Validation Accuracy: 0.697200
# Epoch 54, CIFAR-10 Batch 5:  Loss:     0.0002 Validation Accuracy: 0.692400
# Epoch 55, CIFAR-10 Batch 1:  Loss:     0.0004 Validation Accuracy: 0.690000
# Epoch 55, CIFAR-10 Batch 2:  Loss:     0.0003 Validation Accuracy: 0.689200
# Epoch 55, CIFAR-10 Batch 3:  Loss:     0.0004 Validation Accuracy: 0.688400
# Epoch 55, CIFAR-10 Batch 4:  Loss:     0.0013 Validation Accuracy: 0.687600
# Epoch 55, CIFAR-10 Batch 5:  Loss:     0.0000 Validation Accuracy: 0.694400
# Epoch 56, CIFAR-10 Batch 1:  Loss:     0.0001 Validation Accuracy: 0.682000
# Epoch 56, CIFAR-10 Batch 2:  Loss:     0.0039 Validation Accuracy: 0.696200
# Epoch 56, CIFAR-10 Batch 3:  Loss:     0.0001 Validation Accuracy: 0.702400
# Epoch 56, CIFAR-10 Batch 4:  Loss:     0.0004 Validation Accuracy: 0.687400
# Epoch 56, CIFAR-10 Batch 5:  Loss:     0.0001 Validation Accuracy: 0.677200
# Epoch 57, CIFAR-10 Batch 1:  Loss:     0.0003 Validation Accuracy: 0.695200
# Epoch 57, CIFAR-10 Batch 2:  Loss:     0.0001 Validation Accuracy: 0.690600
# Epoch 57, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy: 0.696200
# Epoch 57, CIFAR-10 Batch 4:  Loss:     0.0004 Validation Accuracy: 0.692000
# Epoch 57, CIFAR-10 Batch 5:  Loss:     0.0000 Validation Accuracy: 0.691400
# Epoch 58, CIFAR-10 Batch 1:  Loss:     0.0001 Validation Accuracy: 0.682800
# Epoch 58, CIFAR-10 Batch 2:  Loss:     0.0003 Validation Accuracy: 0.675400
# Epoch 58, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy: 0.688000
# Epoch 58, CIFAR-10 Batch 4:  Loss:     0.0000 Validation Accuracy: 0.686800
# Epoch 58, CIFAR-10 Batch 5:  Loss:     0.0001 Validation Accuracy: 0.690400
# Epoch 59, CIFAR-10 Batch 1:  Loss:     0.0002 Validation Accuracy: 0.684800
# Epoch 59, CIFAR-10 Batch 2:  Loss:     0.0002 Validation Accuracy: 0.697400
# Epoch 59, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy: 0.689000
# Epoch 59, CIFAR-10 Batch 4:  Loss:     0.0009 Validation Accuracy: 0.697800
# Epoch 59, CIFAR-10 Batch 5:  Loss:     0.0000 Validation Accuracy: 0.686800
# Epoch 60, CIFAR-10 Batch 1:  Loss:     0.0005 Validation Accuracy: 0.695600
# Epoch 60, CIFAR-10 Batch 2:  Loss:     0.0003 Validation Accuracy: 0.691800
# Epoch 60, CIFAR-10 Batch 3:  Loss:     0.0002 Validation Accuracy: 0.697400
# Epoch 60, CIFAR-10 Batch 4:  Loss:     0.0001 Validation Accuracy: 0.689800
# Epoch 60, CIFAR-10 Batch 5:  Loss:     0.0002 Validation Accuracy: 0.694000
# Epoch 61, CIFAR-10 Batch 1:  Loss:     0.0001 Validation Accuracy: 0.696000
# Epoch 61, CIFAR-10 Batch 2:  Loss:     0.0005 Validation Accuracy: 0.686400
# Epoch 61, CIFAR-10 Batch 3:  Loss:     0.0003 Validation Accuracy: 0.687400
# Epoch 61, CIFAR-10 Batch 4:  Loss:     0.0000 Validation Accuracy: 0.679400
# Epoch 61, CIFAR-10 Batch 5:  Loss:     0.0008 Validation Accuracy: 0.690000
# Epoch 62, CIFAR-10 Batch 1:  Loss:     0.0008 Validation Accuracy: 0.694600
# Epoch 62, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy: 0.688800
# Epoch 62, CIFAR-10 Batch 3:  Loss:     0.0001 Validation Accuracy: 0.699200
# Epoch 62, CIFAR-10 Batch 4:  Loss:     0.0004 Validation Accuracy: 0.688000
# Epoch 62, CIFAR-10 Batch 5:  Loss:     0.0004 Validation Accuracy: 0.692200
# Epoch 63, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.690600
# Epoch 63, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy: 0.686600
# Epoch 63, CIFAR-10 Batch 3:  Loss:     0.0003 Validation Accuracy: 0.694200
# Epoch 63, CIFAR-10 Batch 4:  Loss:     0.0003 Validation Accuracy: 0.688800
# Epoch 63, CIFAR-10 Batch 5:  Loss:     0.0000 Validation Accuracy: 0.691200
# Epoch 64, CIFAR-10 Batch 1:  Loss:     0.0002 Validation Accuracy: 0.689400
# Epoch 64, CIFAR-10 Batch 2:  Loss:     0.0003 Validation Accuracy: 0.688600
# Epoch 64, CIFAR-10 Batch 3:  Loss:     0.0001 Validation Accuracy: 0.685000
# Epoch 64, CIFAR-10 Batch 4:  Loss:     0.0000 Validation Accuracy: 0.700800
# Epoch 64, CIFAR-10 Batch 5:  Loss:     0.0002 Validation Accuracy: 0.699400
# Epoch 65, CIFAR-10 Batch 1:  Loss:     0.0001 Validation Accuracy: 0.692400
# Epoch 65, CIFAR-10 Batch 2:  Loss:     0.0003 Validation Accuracy: 0.686600
# Epoch 65, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy: 0.685200
# Epoch 65, CIFAR-10 Batch 4:  Loss:     0.0078 Validation Accuracy: 0.695600
# Epoch 65, CIFAR-10 Batch 5:  Loss:     0.0004 Validation Accuracy: 0.702800
# Epoch 66, CIFAR-10 Batch 1:  Loss:     0.0001 Validation Accuracy: 0.703600
# Epoch 66, CIFAR-10 Batch 2:  Loss:     0.0001 Validation Accuracy: 0.688400
# Epoch 66, CIFAR-10 Batch 3:  Loss:     0.0007 Validation Accuracy: 0.682200
# Epoch 66, CIFAR-10 Batch 4:  Loss:     0.0001 Validation Accuracy: 0.698400
# Epoch 66, CIFAR-10 Batch 5:  Loss:     0.0003 Validation Accuracy: 0.686600
# Epoch 67, CIFAR-10 Batch 1:  Loss:     0.0006 Validation Accuracy: 0.690200
# Epoch 67, CIFAR-10 Batch 2:  Loss:     0.0002 Validation Accuracy: 0.696200
# Epoch 67, CIFAR-10 Batch 3:  Loss:     0.0010 Validation Accuracy: 0.701200
# Epoch 67, CIFAR-10 Batch 4:  Loss:     0.0000 Validation Accuracy: 0.696800
# Epoch 67, CIFAR-10 Batch 5:  Loss:     0.0007 Validation Accuracy: 0.681400
# Epoch 68, CIFAR-10 Batch 1:  Loss:     0.0008 Validation Accuracy: 0.684800
# Epoch 68, CIFAR-10 Batch 2:  Loss:     0.0002 Validation Accuracy: 0.694200
# Epoch 68, CIFAR-10 Batch 3:  Loss:     0.0006 Validation Accuracy: 0.690800
# Epoch 68, CIFAR-10 Batch 4:  Loss:     0.0001 Validation Accuracy: 0.695200
# Epoch 68, CIFAR-10 Batch 5:  Loss:     0.0001 Validation Accuracy: 0.699400
# Epoch 69, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.702600
# Epoch 69, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy: 0.699000
# Epoch 69, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy: 0.694000
# Epoch 69, CIFAR-10 Batch 4:  Loss:     0.0000 Validation Accuracy: 0.694000
# Epoch 69, CIFAR-10 Batch 5:  Loss:     0.0000 Validation Accuracy: 0.692600
# Epoch 70, CIFAR-10 Batch 1:  Loss:     0.0008 Validation Accuracy: 0.704800
# Epoch 70, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy: 0.694400
# Epoch 70, CIFAR-10 Batch 3:  Loss:     0.0001 Validation Accuracy: 0.701800
# Epoch 70, CIFAR-10 Batch 4:  Loss:     0.0001 Validation Accuracy: 0.694600
# Epoch 70, CIFAR-10 Batch 5:  Loss:     0.0001 Validation Accuracy: 0.698600
# Epoch 71, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.686800
# Epoch 71, CIFAR-10 Batch 2:  Loss:     0.0001 Validation Accuracy: 0.699600
# Epoch 71, CIFAR-10 Batch 3:  Loss:     0.0007 Validation Accuracy: 0.683800
# Epoch 71, CIFAR-10 Batch 4:  Loss:     0.0004 Validation Accuracy: 0.699800
# Epoch 71, CIFAR-10 Batch 5:  Loss:     0.0003 Validation Accuracy: 0.701400
# Epoch 72, CIFAR-10 Batch 1:  Loss:     0.0002 Validation Accuracy: 0.694800
# Epoch 72, CIFAR-10 Batch 2:  Loss:     0.0001 Validation Accuracy: 0.690600
# Epoch 72, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy: 0.700400
# Epoch 72, CIFAR-10 Batch 4:  Loss:     0.0008 Validation Accuracy: 0.699600
# Epoch 72, CIFAR-10 Batch 5:  Loss:     0.0000 Validation Accuracy: 0.711800
# Epoch 73, CIFAR-10 Batch 1:  Loss:     0.0004 Validation Accuracy: 0.703800
# Epoch 73, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy: 0.693200
# Epoch 73, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy: 0.688600
# Epoch 73, CIFAR-10 Batch 4:  Loss:     0.0000 Validation Accuracy: 0.697600
# Epoch 73, CIFAR-10 Batch 5:  Loss:     0.0000 Validation Accuracy: 0.695600
# Epoch 74, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.693400
# Epoch 74, CIFAR-10 Batch 2:  Loss:     0.0004 Validation Accuracy: 0.680000
# Epoch 74, CIFAR-10 Batch 3:  Loss:     0.0001 Validation Accuracy: 0.692200
# Epoch 74, CIFAR-10 Batch 4:  Loss:     0.0002 Validation Accuracy: 0.695000
# Epoch 74, CIFAR-10 Batch 5:  Loss:     0.0002 Validation Accuracy: 0.692200
# Epoch 75, CIFAR-10 Batch 1:  Loss:     0.0002 Validation Accuracy: 0.688800
# Epoch 75, CIFAR-10 Batch 2:  Loss:     0.0001 Validation Accuracy: 0.696000
# Epoch 75, CIFAR-10 Batch 3:  Loss:     0.0003 Validation Accuracy: 0.692200
# Epoch 75, CIFAR-10 Batch 4:  Loss:     0.0008 Validation Accuracy: 0.689400
# Epoch 75, CIFAR-10 Batch 5:  Loss:     0.0001 Validation Accuracy: 0.697600
# Epoch 76, CIFAR-10 Batch 1:  Loss:     0.0006 Validation Accuracy: 0.699800
# Epoch 76, CIFAR-10 Batch 2:  Loss:     0.0001 Validation Accuracy: 0.697600
# Epoch 76, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy: 0.698000
# Epoch 76, CIFAR-10 Batch 4:  Loss:     0.0001 Validation Accuracy: 0.694200
# Epoch 76, CIFAR-10 Batch 5:  Loss:     0.0001 Validation Accuracy: 0.698400
# Epoch 77, CIFAR-10 Batch 1:  Loss:     0.0002 Validation Accuracy: 0.685800
# Epoch 77, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy: 0.701800
# Epoch 77, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy: 0.698800
# Epoch 77, CIFAR-10 Batch 4:  Loss:     0.0000 Validation Accuracy: 0.695600
# Epoch 77, CIFAR-10 Batch 5:  Loss:     0.0001 Validation Accuracy: 0.692600
# Epoch 78, CIFAR-10 Batch 1:  Loss:     0.0002 Validation Accuracy: 0.692800
# Epoch 78, CIFAR-10 Batch 2:  Loss:     0.0001 Validation Accuracy: 0.688600
# Epoch 78, CIFAR-10 Batch 3:  Loss:     0.0001 Validation Accuracy: 0.688200
# Epoch 78, CIFAR-10 Batch 4:  Loss:     0.0001 Validation Accuracy: 0.686000
# Epoch 78, CIFAR-10 Batch 5:  Loss:     0.0002 Validation Accuracy: 0.701200
# Epoch 79, CIFAR-10 Batch 1:  Loss:     0.0005 Validation Accuracy: 0.688200
# Epoch 79, CIFAR-10 Batch 2:  Loss:     0.0001 Validation Accuracy: 0.695200
# Epoch 79, CIFAR-10 Batch 3:  Loss:     0.0002 Validation Accuracy: 0.699800
# Epoch 79, CIFAR-10 Batch 4:  Loss:     0.0000 Validation Accuracy: 0.696000
# Epoch 79, CIFAR-10 Batch 5:  Loss:     0.0001 Validation Accuracy: 0.697400
# Epoch 80, CIFAR-10 Batch 1:  Loss:     0.0000 Validation Accuracy: 0.697400
# Epoch 80, CIFAR-10 Batch 2:  Loss:     0.0000 Validation Accuracy: 0.697200
# Epoch 80, CIFAR-10 Batch 3:  Loss:     0.0000 Validation Accuracy: 0.698000
# Epoch 80, CIFAR-10 Batch 4:  Loss:     0.0000 Validation Accuracy: 0.699000
# Epoch 80, CIFAR-10 Batch 5:  Loss:     0.0000 Validation Accuracy: 0.692800

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# INFO:tensorflow:Restoring parameters from ./image_classification
# Testing Accuracy: 0.6833984375

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. That's because there are many more techniques that can be applied to your model and we recemmond that once you are done with this project, you explore!
#
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
